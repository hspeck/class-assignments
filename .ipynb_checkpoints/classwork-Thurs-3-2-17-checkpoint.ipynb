# %%
#opening the file
in_file = '/home/eeb177-student/Desktop/eeb-177/class-assignments/canids/cleaned_canids.csv'
with open(in_file, "r") as ff:
    canid_recs = ff.readlines()

# %%
#let's make a dictionary, using defaultdict
from collections import defaultdict

species_ranges = defaultdict(list)
for line in canid_recs:
    species = line.split(",")[5]
    min_age = float(line.split('","')[10])
    max_age = float(line.split('","')[11])
    
    mean_age = (min_age + max_age)/2
    
    species_ranges[species].append(mean_age) #adds species as keys and mean ages as elements to list of ages
    #print(mean_age)

# %%
# get oldest and youngest range of fossils from each species

for key in species_ranges.keys():
    ages = species_ranges[key]
    maxage = max(ages)
    minage = min(ages)
    genus = key.split(" ")[0]
    print(key, minage, maxage)
# Out:
# "Phlaocyon yatkolai" 18.2 18.2
# "Protocyon orcesi" 0.39635000000000004 0.39635000000000004
# "Cerdocyon texanus" 3.35 7.6000000000000005
# "Paratomarctus euthos" 9.25 14.1815
# "Ectopocynus intermedius" 25.615000000000002 25.615000000000002
# "Canidae" 0.06885 35.55
# "Hesperocyoninae" 22.615000000000002 28.55
# "Xenocyon" 0.4535 1.6845
# "Enhydrocyon stenocephalus" 25.615000000000002 25.615000000000002
# "Sunkahetanka geringensis" 25.615000000000002 28.55
# "Borophagus diversidens" 3.35 3.35
# "Leptocyon matthewi" 9.25 11.95
# "Mesocyon brachyops" 25.615000000000002 25.615000000000002
# "Urocyon galushai" 3.35 3.35
# "Aelurodon mcgrewi" 14.1815 14.785
# "Canis lupus" 0.00585 3.0940000000000003
# "Lycaon" 0.4535 3.0940000000000003
# "Eucyon" 3.9605 8.470500000000001
# "Carpocyon" 14.1815 14.785
# "Cormocyon" 28.55 28.55
# "Aelurodon montanensis" 14.785 14.785
# "Osbornodon sesnoni" 25.615000000000002 32.05
# "Ectopocynus antiquus" 25.615000000000002 32.05
# "Dusicyon" 0.00585 1.29985
# "Caninae" 0.06885 25.55
# "Chrysocyon" 1.294 1.294
# "Canis thooides" 3.35 3.35
# "Eucyon davisi" 3.35 14.1815
# "Chailicyon crassidens" 42.900000000000006 42.900000000000006
# "Urocyon minicephalus" 1.05 1.05
# "Leptocyon leidyi" 14.785 22.615000000000002
# "Archaeocyon pavidus" 25.615000000000002 32.05
# "Phlaocyon mariae" 18.2 18.2
# "Nyctereutes abdeslami" 3.0940000000000003 3.0940000000000003
# "Cynarctus" 11.95 14.785
# "Cynarctoides gawnae" 14.1815 18.2
# "Alopex" 2.6723500000000002 2.6723500000000002
# "Protocyon" 0.06885 1.29985
# "Hesperocyon coloradensis" 33.599999999999994 33.599999999999994
# "Carpocyon compressus" 13.135000000000002 14.785
# "Canis familiaris" 0.00585 1.294
# "Enhydrocyon crassidens" 22.615000000000002 28.55
# "Urocyon cinereoargenteus" 0.00585 3.35
# "Eucyon skinneri" 11.95 11.95
# "Chrysocyon brachyurus" 1.294 1.6845
# "Enhydrocyon" 25.55 32.05
# "Paratomarctus temerarius" 9.25 14.895
# "Cynodictis lacustris" 35.55 35.95
# "Chrysocyon nearcticus" 3.35 3.35
# "Canis cedazoensis" 1.05 1.05
# "Canis apolloniensis" 1.6845 1.6845
# "Paraenhydrocyon josephi" 22.615000000000002 25.615000000000002
# "Xenocyon lycaonoides" 0.4535 1.6845
# "Psalidocyon marianae" 14.785 18.2
# "Xenocyon texanus" 1.05 1.05
# "Enhydrocyon basilatus" 22.615000000000002 22.615000000000002
# "Paraenhydrocyon wallovianus" 22.615000000000002 25.615000000000002
# "Tomarctus brevirostris" 14.1815 18.2
# "Leptocyon vulpinus" 18.2 25.615000000000002
# "Phlaocyon leucosteus" 18.2 22.615000000000002
# "Phlaocyon annectens" 22.615000000000002 22.615000000000002
# "Cormocyon copei" 14.1815 28.55
# "Otarocyon macdonaldi" 33.599999999999994 33.599999999999994
# "Hesperocyon" 25.615000000000002 43.3
# "Epicyon haydeni" 7.6000000000000005 18.2
# "Theriodictis floridanus" 3.35 3.35
# "Aelurodon stirtoni" 11.95 14.785
# "Leptocyon mollis" 25.615000000000002 25.615000000000002
# "Phlaocyon marslandensis" 18.2 18.2
# "Desmocyon" 22.615000000000002 22.615000000000002
# "Cynarctus galushai" 14.785 14.785
# "Vulpes kernensis" 11.95 11.95
# "Metalopex bakeri" 7.6000000000000005 7.6000000000000005
# "Oxetocyon cuspidatus" 32.05 32.05
# "Vulpes stenognathus" 1.05 14.785
# "Cormocyon haydeni" 22.615000000000002 25.615000000000002
# "Canini" 3.35 7.6000000000000005
# "Borophagus secundus" 7.6000000000000005 14.1815
# "Phlaocyon" 18.2 25.615000000000002
# "Canis lepophagus" 0.06885 7.6000000000000005
# "Nyctereutes procyonoides" 0.06885 1.294
# "Protepicyon raki" 14.785 14.785
# "Phlaocyon multicuspus" 22.615000000000002 22.615000000000002
# "Euoplocyon brachygnathus" 14.785 18.2
# "Cynarctus saxatilis" 14.785 14.785
# "Cynarctoides luskensis" 22.615000000000002 25.615000000000002
# "Vulpes velox" 0.063 3.35
# "Vulpes cascadensis" 0.06885 0.06885
# "Leptocyon gregorii" 22.615000000000002 22.615000000000002
# "Archaeocyon leptodus" 25.615000000000002 32.05
# "Epicyon aelurodontoides" 7.6000000000000005 7.6000000000000005
# "Rhizocyon oregonensis" 25.615000000000002 25.615000000000002
# "Cerdocyon avius" 3.35 3.9605
# "Canis" 0.00585 12.809000000000001
# "Paracynarctus sinclairi" 14.785 18.2
# "Vulpes" 0.00585 7.6000000000000005
# "Borophagus pugnator" 7.6000000000000005 14.1815
# "Vulpini" 0.06885 0.06885
# "Cynarctoides roii" 25.615000000000002 28.55
# "Canis armbrusteri" 0.06885 2.6
# "Canis mesomelas" 0.00585 3.9605
# "Leptocyon" 11.95 25.615000000000002
# "Mesocyon coryphaeus" 25.615000000000002 25.615000000000002
# "Paraenhydrocyon robustus" 22.615000000000002 22.615000000000002
# "Vulpes vulpes" 0.00585 2.894
# "Cubacyon transversidens" 1.294 1.294
# "Aelurodon asthenostylus" 14.785 18.2
# "Osbornodon brachypus" 18.2 22.615000000000002
# "Aelurodon" 8.470500000000001 14.785
# "Cynodesmus martini" 25.615000000000002 25.615000000000002
# "Canis aureus" 0.00585 3.0940000000000003
# "Mesocyon temnodon" 22.615000000000002 33.599999999999994
# "Borophagus orc" 4.4665 7.6000000000000005
# "Pseudalopex gymnocercus" 0.00585 1.6845
# "Cynarctoides whistleri" 18.2 18.2
# "Cynarctoides lemur" 22.615000000000002 28.55
# "Borophagus littoralis" 11.95 14.1815
# "Cynotherium" 0.06885 1.80585
# "Nyctereutes" 1.29985 7.0165
# "Carpocyon robustus" 11.95 14.1815
# "Osbornodon wangi" 25.615000000000002 25.615000000000002
# "Metalopex macconnelli" 11.95 14.1815
# "Osbornodon renjiei" 32.05 33.599999999999994
# "Enhydrocyon pahinsintewakpa" 22.615000000000002 28.55
# "Carpocyon webbi" 7.6000000000000005 14.785
# "Urocyon citrinus" 3.35 3.35
# "Borophaginae" 7.6000000000000005 22.615000000000002
# "Alopex lagopus" 0.00585 1.05
# "Osbornodon fricki" 14.785 18.2
# "Vulpes vulpes macroura" 0.06885 0.06885
# "Hesperocyon gregarius" 32.05 38.8
# "Vulpes chama" 0.00585 1.6845
# "Cynodictis" 31.0 52.2
# "Speothos" 1.29985 1.29985
# "Otocyon" 0.39635000000000004 3.0940000000000003
# "Dusicyon avus" 0.06885 0.3965
# "Leptocyon vafer" 11.95 14.785
# "Theriodictis" 0.06885 1.6845
# "Borophagus dudleyi" 4.4665 4.4665
# "Cynarctus voorhiesi" 11.95 11.95
# "Phlaocyon latidens" 25.615000000000002 32.05
# "Metatomarctus" 14.1815 14.1815
# "Phlaocyon minor" 18.2 25.615000000000002
# "Aelurodon taxoides" 7.6000000000000005 14.1815
# "Desmocyon matthewi" 18.2 18.2
# "Tomarctus" 11.95 14.895
# "Phlaocyon taylori" 25.615000000000002 27.8
# "Leptocyon delicatus" 25.615000000000002 25.615000000000002
# "Cynarctoides acridens" 14.785 25.615000000000002
# "Archaeocyon falkenbachi" 25.615000000000002 25.615000000000002
# "Phlaocyon achoros" 22.615000000000002 22.615000000000002
# "Cuon alpinus" 0.06885 1.29985
# "Leptocyon tejonensis" 11.95 11.95
# "Otocyon megalotis" 0.00585 1.29985
# "Cuon" 0.06885 0.4535
# "Osbornodon scitulus" 18.2 18.2
# "Lycaon pictus" 0.00585 1.29985
# "Tomarctus hippophaga" 14.1815 18.2
# "Caedocyon tedfordi" 25.615000000000002 25.615000000000002
# "Paracynarctus kelloggi" 14.1815 18.2
# "Tephrocyon rurestris" 14.1815 14.785
# "Canis latrans" 0.00585 3.35
# "Leptocyon douglassi" 25.615000000000002 28.55
# "Dusicyon sechurae" 0.39635000000000004 0.39635000000000004
# "Canis edwardii" 1.05 14.1815
# "Otarocyon cooki" 25.615000000000002 28.55
# "Osbornodon iamonensis" 18.2 19.5
# "Aelurodon ferox" 9.25 14.785
# "Neovulpavus washakius" 43.3 43.3
# "Oxetocyon" 32.05 32.05
# "Ectopocynus simplicidens" 18.2 18.2
# "Cynodesmus thooides" 25.615000000000002 32.05
# "Protocyon troglodytes" 0.063 1.294
# "Cynarctoides emryi" 18.2 18.2
# "Protomarctus optatus" 14.1815 18.205000000000002
# "Gobicyon" 10.6515 12.719999999999999
# "Canis dirus" 0.06885 1.6845
# "Mesocyon" 25.615000000000002 25.615000000000002
# "Dusicyon culpaeus" 1.29985 1.29985
# "Cynarctus marylandica" 14.895 18.205000000000002
# "Canis (Pseudalopex)" 0.06885 1.29985
# "Metatomarctus canavus" 14.1815 18.2
# "Borophagus parvus" 7.6000000000000005 7.6000000000000005
# "Cynarctus crucidens" 8.470500000000001 14.1815
# "Cynarctus wangi" 14.785 14.785
# "Protemnocyon inflatus" 33.599999999999994 33.599999999999994
# "Urocyon webbi" 7.6000000000000005 7.6000000000000005
# "Metalopex merriami" 7.6000000000000005 14.1815
# "Canis proplatensis" 1.6845 1.6845
# "Protocyon tarijensis" 1.6845 1.6845
# "Cynotherium sardous" 0.06885 1.80585
# "Desmocyon thomsoni" 14.1815 25.615000000000002
# "Epicyon saevus" 7.6000000000000005 14.785
# "Euoplocyon spissidens" 18.2 18.2
# "Cynarctoides harlowi" 22.615000000000002 22.615000000000002
# "Canis anthus" 1.294 1.294
# "Carpocyon limosus" 7.6000000000000005 7.6000000000000005
# "Canis adustus" 0.00585 3.0940000000000003
# "Canis rufus" 0.06885 3.35
# "Philotrox condoni" 25.615000000000002 28.55
# "Cerdocyon thous" 0.00585 0.063
# "Epicyon" 7.6000000000000005 11.95
# "Urocyon progressus" 3.35 3.35
# "Borophagus hilli" 3.35 14.1815
# "Canis ferox" 3.35 7.6000000000000005
# "Urocyon" 0.06885 11.95
# "Borophagus" 3.35 14.1815
# "Speothos venaticus" 0.00585 0.00585
# "Microtomarctus conferta" 14.1815 18.2
# "Vulpes mathisoni" 4.4665 4.4665
# "Aelurodon wheelerianus" 18.2 18.2
